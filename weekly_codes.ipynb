# %%
from google.colab import userdata
OPENAI_API_KEY = userdata.get('secretName')

# %%
import os
from getpass import getpass
# Set the API key securely
os.environ["OPENAI_API_KEY"] = getpass(userdata.get('secretName'))
